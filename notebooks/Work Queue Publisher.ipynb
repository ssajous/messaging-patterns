# %% [markdown]
# # Work Queue Publisher

# %% [markdown]
# https://www.rabbitmq.com/tutorials/tutorial-two-python.html

# %%
import pika

# %%
RABBIT_CONNECTION = 'amqp://guest:guest@rabbit:5672/'
QUEUE_NAME = 'work_queue_example'

# %%
connection = pika.BlockingConnection(
    pika.connection.URLParameters(RABBIT_CONNECTION))
rabbit_channel = connection.channel()

# %%
rabbit_channel.queue_declare(queue=QUEUE_NAME, durable=True)
# Out:
# <METHOD(['channel_number=1', 'frame_type=1', "method=<Queue.DeclareOk(['consumer_count=3', 'message_count=0', 'queue=work_queue_example'])>"])>

# %%
def fill_queue(channel, messages=20, start=1):
    for message_num in range(start, messages + start):
        channel.basic_publish(
            exchange='',
            routing_key=QUEUE_NAME,
            body=f'Work message # {message_num}',
            properties=pika.BasicProperties(delivery_mode=pika.spec.PERSISTENT_DELIVERY_MODE))
        print(f'Message {message_num} sent')

# %%
fill_queue(rabbit_channel, start=200, messages=200)
# Out:
# Message 200 sent
# Message 201 sent
# Message 202 sent
# Message 203 sent
# Message 204 sent
# Message 205 sent
# Message 206 sent
# Message 207 sent
# Message 208 sent
# Message 209 sent
# Message 210 sent
# Message 211 sent
# Message 212 sent
# Message 213 sent
# Message 214 sent
# Message 215 sent
# Message 216 sent
# Message 217 sent
# Message 218 sent
# Message 219 sent
# Message 220 sent
# Message 221 sent
# Message 222 sent
# Message 223 sent
# Message 224 sent
# Message 225 sent
# Message 226 sent
# Message 227 sent
# Message 228 sent
# Message 229 sent
# Message 230 sent
# Message 231 sent
# Message 232 sent
# Message 233 sent
# Message 234 sent
# Message 235 sent
# Message 236 sent
# Message 237 sent
# Message 238 sent
# Message 239 sent
# Message 240 sent
# Message 241 sent
# Message 242 sent
# Message 243 sent
# Message 244 sent
# Message 245 sent
# Message 246 sent
# Message 247 sent
# Message 248 sent
# Message 249 sent
# Message 250 sent
# Message 251 sent
# Message 252 sent
# Message 253 sent
# Message 254 sent
# Message 255 sent
# Message 256 sent
# Message 257 sent
# Message 258 sent
# Message 259 sent
# Message 260 sent
# Message 261 sent
# Message 262 sent
# Message 263 sent
# Message 264 sent
# Message 265 sent
# Message 266 sent
# Message 267 sent
# Message 268 sent
# Message 269 sent
# Message 270 sent
# Message 271 sent
# Message 272 sent
# Message 273 sent
# Message 274 sent
# Message 275 sent
# Message 276 sent
# Message 277 sent
# Message 278 sent
# Message 279 sent
# Message 280 sent
# Message 281 sent
# Message 282 sent
# Message 283 sent
# Message 284 sent
# Message 285 sent
# Message 286 sent
# Message 287 sent
# Message 288 sent
# Message 289 sent
# Message 290 sent
# Message 291 sent
# Message 292 sent
# Message 293 sent
# Message 294 sent
# Message 295 sent
# Message 296 sent
# Message 297 sent
# Message 298 sent
# Message 299 sent
# Message 300 sent
# Message 301 sent
# Message 302 sent
# Message 303 sent
# Message 304 sent
# Message 305 sent
# Message 306 sent
# Message 307 sent
# Message 308 sent
# Message 309 sent
# Message 310 sent
# Message 311 sent
# Message 312 sent
# Message 313 sent
# Message 314 sent
# Message 315 sent
# Message 316 sent
# Message 317 sent
# Message 318 sent
# Message 319 sent
# Message 320 sent
# Message 321 sent
# Message 322 sent
# Message 323 sent
# Message 324 sent
# Message 325 sent
# Message 326 sent
# Message 327 sent
# Message 328 sent
# Message 329 sent
# Message 330 sent
# Message 331 sent
# Message 332 sent
# Message 333 sent
# Message 334 sent
# Message 335 sent
# Message 336 sent
# Message 337 sent
# Message 338 sent
# Message 339 sent
# Message 340 sent
# Message 341 sent
# Message 342 sent
# Message 343 sent
# Message 344 sent
# Message 345 sent
# Message 346 sent
# Message 347 sent
# Message 348 sent
# Message 349 sent
# Message 350 sent
# Message 351 sent
# Message 352 sent
# Message 353 sent
# Message 354 sent
# Message 355 sent
# Message 356 sent
# Message 357 sent
# Message 358 sent
# Message 359 sent
# Message 360 sent
# Message 361 sent
# Message 362 sent
# Message 363 sent
# Message 364 sent
# Message 365 sent
# Message 366 sent
# Message 367 sent
# Message 368 sent
# Message 369 sent
# Message 370 sent
# Message 371 sent
# Message 372 sent
# Message 373 sent
# Message 374 sent
# Message 375 sent
# Message 376 sent
# Message 377 sent
# Message 378 sent
# Message 379 sent
# Message 380 sent
# Message 381 sent
# Message 382 sent
# Message 383 sent
# Message 384 sent
# Message 385 sent
# Message 386 sent
# Message 387 sent
# Message 388 sent
# Message 389 sent
# Message 390 sent
# Message 391 sent
# Message 392 sent
# Message 393 sent
# Message 394 sent
# Message 395 sent
# Message 396 sent
# Message 397 sent
# Message 398 sent
# Message 399 sent
